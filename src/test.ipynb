# %%
from main import test_map0
caught, numofmoves = test_map0(N=100)
print('Number of moves made: {}; Target caught: {}.\n'.format(numofmoves, caught))
# Out:
#   0%|          | 0/100000 [00:00<?, ?it/s]
# robotpos = (5,2)
# targetpos = (4,3)
# total time = 0.0064373016357421875s
# average moving time/step = 0.0012874603271484375s
#   0%|          | 4/100000 [00:00<2:10:23, 12.78it/s]
# Number of moves made: 5; Target caught: True.

# %%
from main import test_map1
caught, numofmoves = test_map1(N=1000)
print('Number of moves made: {}; Target caught: {}.\n'.format(numofmoves, caught))
# Out:
#   2%|▏         | 1635/100000 [02:02<17:27, 93.94it/s]
# robotpos = (703,2078)
# targetpos = (704,2079)
# total time = 119.92928552627563s
# average moving time/step = 0.07299408735622376s
#   2%|▏         | 1642/100000 [02:02<2:02:30, 13.38it/s]
# Number of moves made: 1643; Target caught: True.

# %%
from main import test_map1b
caught, numofmoves = test_map1b(N=1000)
print('Number of moves made: {}; Target caught: {}.\n'.format(numofmoves, caught))
# Out:
#   8%|▊         | 7829/100000 [09:35<16:53, 90.95it/s]
# robotpos = (1739,1901)
# targetpos = (1739,1902)
# total time = 564.6154975891113s
# average moving time/step = 0.07210005077118009s
#   8%|▊         | 7830/100000 [09:36<1:53:02, 13.59it/s]
# Number of moves made: 7831; Target caught: True.

# %%
from main import test_map1b
caught, numofmoves = test_map1b(N=10000)
print('Number of moves made: {}; Target caught: {}.\n'.format(numofmoves, caught))
# Out:
#   4%|▎         | 3698/100000 [39:11<22:44, 70.59it/s]
# robotpos = (1739,1901)
# targetpos = (1739,1902)
# total time = 2342.230469942093s
# average moving time/step = 0.630988811945607s
#   4%|▎         | 3711/100000 [39:11<16:57:01,  1.58it/s]
# Number of moves made: 3712; Target caught: True.

# %%
from main import test_map1b
caught, numofmoves = test_map1b(N=5000)
print('Number of moves made: {}; Target caught: {}.\n'.format(numofmoves, caught))
# Out:
#   5%|▌         | 5044/100000 [28:31<21:56, 72.13it/s]
# robotpos = (1739,1901)
# targetpos = (1740,1902)
# total time = 1699.2819690704346s
# average moving time/step = 0.3359592663247202s
#   5%|▌         | 5057/100000 [28:31<8:55:34,  2.95it/s]
# Number of moves made: 5058; Target caught: True.

# %%
from main import test_map1b
caught, numofmoves = test_map1b(N=20000)
print('Number of moves made: {}; Target caught: {}.\n'.format(numofmoves, caught))
# Out:
#   3%|▎         | 3430/100000 [1:05:53<20:48, 77.33it/s]
# robotpos = (1739,1901)
# targetpos = (1739,1902)
# total time = 3944.9256739616394s
# average moving time/step = 1.1457814911303048s
#   3%|▎         | 3442/100000 [1:05:54<30:48:43,  1.15s/it]
# Number of moves made: 3443; Target caught: True.

# %%
from main import test_map1b
caught, numofmoves = test_map1b(N=20000, K=10)
print('Number of moves made: {}; Target caught: {}.\n'.format(numofmoves, caught))
# Out:
#   4%|▍         | 3888/100000 [06:49<06:02, 265.45it/s]
# robotpos = (1739,1900)
# targetpos = (1740,1899)
# total time = 406.5676157474518s
# average moving time/step = 0.10395490047237325s
#   4%|▍         | 3910/100000 [06:49<2:47:52,  9.54it/s]
# Number of moves made: 3911; Target caught: True.

# %%
from main import test_map1b
caught, numofmoves = test_map1b(N=20000, K=100)
print('Number of moves made: {}; Target caught: {}.\n'.format(numofmoves, caught))
# Out:
#   3%|▎         | 3087/100000 [00:42<05:30, 292.85it/s]
# robotpos = (1740,1901)
# targetpos = (1740,1902)
# total time = 41.872703552246094s
# average moving time/step = 0.01313447413809476s
#   3%|▎         | 3187/100000 [00:43<21:50, 73.85it/s]
# Number of moves made: 3188; Target caught: True.

# %%
from main import test_map1b
caught, numofmoves = test_map1b(N=30000, K=100)
print('Number of moves made: {}; Target caught: {}.\n'.format(numofmoves, caught))
# Out:
#   3%|▎         | 3062/100000 [00:58<07:49, 206.35it/s]
# robotpos = (1740,1901)
# targetpos = (1739,1902)
# total time = 57.34682631492615s
# average moving time/step = 0.01776543566137737s
#   3%|▎         | 3227/100000 [00:58<29:17, 55.06it/s]
# Number of moves made: 3228; Target caught: True.

# %%
from main import test_map2
caught, numofmoves = test_map2(N=100)
print('Number of moves made: {}; Target caught: {}.\n'.format(numofmoves, caught))
# Out:
#   0%|          | 0/100000 [00:00<?, ?it/s]
# robotpos = (5,8)
# targetpos = (5,9)
# total time = 0.02120041847229004s
# average moving time/step = 0.0017667015393575032s
#   0%|          | 11/100000 [00:00<27:15, 61.14it/s]
# Number of moves made: 12; Target caught: True.

# %%
from main import test_map3
caught, numofmoves = test_map3(N=100)
print('Number of moves made: {}; Target caught: {}.\n'.format(numofmoves, caught))
# Out:
#   0%|          | 235/100000 [00:01<11:31, 144.32it/s]
# robotpos = (435,402)
# targetpos = (435,403)
# total time = 1.815265417098999s
# average moving time/step = 0.007501096764871897s
#   0%|          | 241/100000 [00:02<14:40, 113.28it/s]
# Number of moves made: 242; Target caught: True.

# %%
from main import test_map3
caught, numofmoves = test_map3(N=10000)
print('Number of moves made: {}; Target caught: {}.\n'.format(numofmoves, caught))
# Out:
#   0%|          | 217/100000 [00:23<34:55, 47.62it/s]
# robotpos = (435,403)
# targetpos = (436,402)
# total time = 23.25040054321289s
# average moving time/step = 0.10379643099648612s
#   0%|          | 223/100000 [00:23<2:57:35,  9.36it/s]
# Number of moves made: 224; Target caught: True.

# %%
from main import test_map3b
caught, numofmoves = test_map3b(N=100)
print('Number of moves made: {}; Target caught: {}.\n'.format(numofmoves, caught))
# Out:
#   2%|▏         | 2225/100000 [00:17<11:38, 139.92it/s]
# robotpos = (435,402)
# targetpos = (436,403)
# total time = 16.48219132423401s
# average moving time/step = 0.007374582247979422s
#   2%|▏         | 2234/100000 [00:17<13:04, 124.63it/s]
# Number of moves made: 2235; Target caught: True.

# %%
from main import test_map3b
caught, numofmoves = test_map3b(N=1000)
print('Number of moves made: {}; Target caught: {}.\n'.format(numofmoves, caught))
# Out:
#   1%|          | 624/100000 [00:35<17:17, 95.77it/s]
# robotpos = (435,402)
# targetpos = (435,403)
# total time = 34.60974597930908s
# average moving time/step = 0.05390926165001415s
#   1%|          | 641/100000 [00:35<1:31:55, 18.01it/s]
# Number of moves made: 642; Target caught: True.

# %%
from main import test_map3b
caught, numofmoves = test_map3b(N=10000)
print('Number of moves made: {}; Target caught: {}.\n'.format(numofmoves, caught))
# Out:
#   0%|          | 389/100000 [01:18<14:49, 111.95it/s]
# robotpos = (435,403)
# targetpos = (436,402)
# total time = 77.7575089931488s
# average moving time/step = 0.1934266392864398s
#   0%|          | 401/100000 [01:18<5:25:29,  5.10it/s]
# Number of moves made: 402; Target caught: True.

# %%
from main import test_map3c
caught, numofmoves = test_map3c(N=1000)
print('Number of moves made: {}; Target caught: {}.\n'.format(numofmoves, caught))
# Out:
#   1%|          | 982/100000 [00:56<05:34, 296.29it/s]
# robotpos = (435,403)
# targetpos = (436,402)
# total time = 55.21419024467468s
# average moving time/step = 0.05319286150739372s
#   1%|          | 1037/100000 [00:56<1:30:09, 18.29it/s]
# Number of moves made: 1038; Target caught: True.

# %%
from main import test_map3c
caught, numofmoves = test_map3c(N=10000)
print('Number of moves made: {}; Target caught: {}.\n'.format(numofmoves, caught))
# Out:
#   1%|          | 1248/100000 [09:02<16:30, 99.70it/s]
# robotpos = (435,402)
# targetpos = (436,403)
# total time = 539.9344186782837s
# average moving time/step = 0.42615186951719314s
#   1%|▏         | 1266/100000 [09:02<11:45:36,  2.33it/s]
# Number of moves made: 1267; Target caught: True.

# %%
from main import test_map3c
caught, numofmoves = test_map3c(N=20000)
print('Number of moves made: {}; Target caught: {}.\n'.format(numofmoves, caught))
# Out:
#   1%|          | 805/100000 [07:49<17:24, 95.01it/s]
# robotpos = (435,402)
# targetpos = (436,403)
# total time = 467.60773396492004s
# average moving time/step = 0.5640624052652835s
#   1%|          | 828/100000 [07:49<15:37:19,  1.76it/s]
# Number of moves made: 829; Target caught: True.

# %%
from main import test_map4
caught, numofmoves = test_map4(N=100)
print('Number of moves made: {}; Target caught: {}.\n'.format(numofmoves, caught))
# Out:
#   0%|          | 0/100000 [00:00<?, ?it/s]
# robotpos = (5,5)
# targetpos = (5,5)
# total time = 0.005798816680908203s
# average moving time/step = 0.0006443129645453559s
#   0%|          | 8/100000 [00:00<36:29, 45.67it/s]
# Number of moves made: 9; Target caught: True.

# %%
from main import test_map5
caught, numofmoves = test_map5(N=100)
print('Number of moves made: {}; Target caught: {}.\n'.format(numofmoves, caught))
# Out:
#   0%|          | 268/100000 [00:01<09:33, 174.04it/s]
# robotpos = (40,69)
# targetpos = (41,68)
# total time = 1.3427929878234863s
# average moving time/step = 0.004812878092557299s
#   0%|          | 278/100000 [00:01<09:50, 168.84it/s]
# Number of moves made: 279; Target caught: True.

# %%
from main import test_map5
caught, numofmoves = test_map5(N=1000)
print('Number of moves made: {}; Target caught: {}.\n'.format(numofmoves, caught))
# Out:
#   0%|          | 128/100000 [00:02<08:47, 189.26it/s]
# robotpos = (26,34)
# targetpos = (27,35)
# total time = 2.4018006324768066s
# average moving time/step = 0.015801319950505308s
#   0%|          | 151/100000 [00:02<29:17, 56.81it/s]
# Number of moves made: 152; Target caught: True.

# %%
from main import test_map5
caught, numofmoves = test_map5(N=10000)
print('Number of moves made: {}; Target caught: {}.\n'.format(numofmoves, caught))
# Out:
#   0%|          | 61/100000 [00:02<27:52, 59.77it/s]
# robotpos = (1,69)
# targetpos = (0,68)
# total time = 2.17510986328125s
# average moving time/step = 0.02529197515443314s
#   0%|          | 85/100000 [00:02<47:04, 35.38it/s]
# Number of moves made: 86; Target caught: True.

# %%
from main import test_map6
caught, numofmoves = test_map6(N=100)
print('Number of moves made: {}; Target caught: {}.\n'.format(numofmoves, caught))
# Out:
#   0%|          | 35/100000 [00:00<09:19, 178.83it/s]
# robotpos = (33,35)
# targetpos = (33,36)
# total time = 0.19545412063598633s
# average moving time/step = 0.004886353015899658s
#   0%|          | 39/100000 [00:00<15:55, 104.61it/s]
# Number of moves made: 40; Target caught: True.

# %%
from main import test_map6
caught, numofmoves = test_map6(N=1000)
print('Number of moves made: {}; Target caught: {}.\n'.format(numofmoves, caught))
# Out:
#   0%|          | 21/100000 [00:00<24:13, 68.78it/s]
# robotpos = (33,35)
# targetpos = (33,36)
# total time = 0.37744736671447754s
# average moving time/step = 0.009436184167861938s
#   0%|          | 39/100000 [00:00<26:04, 63.91it/s]
# Number of moves made: 40; Target caught: True.

# %%
from main import test_map7
caught, numofmoves = test_map7(N=10000, K=1000, epsilon=5)
print('Number of moves made: {}; Target caught: {}.\n'.format(numofmoves, caught))
# Out:
#  19%|█▊        | 18577/100000 [00:48<00:55, 1471.99it/s]
# robotpos = (4997,4904)
# targetpos = (4998,4903)
# total time = 42.437089920043945s
# average moving time/step = 0.002272887896740611s
#  19%|█▊        | 18670/100000 [00:49<03:35, 376.91it/s]
# Number of moves made: 18671; Target caught: True.

# %%
from main import test_map7
caught, numofmoves = test_map7(N=30000, K=1000, epsilon=5)
print('Number of moves made: {}; Target caught: {}.\n'.format(numofmoves, caught))
# Out:
#  34%|███▍      | 34070/100000 [04:23<00:38, 1699.58it/s]
# robotpos = (2,4007)
# targetpos = (2,4006)
# total time = 250.26621389389038s
# average moving time/step = 0.007312380245256111s
#  34%|███▍      | 34224/100000 [04:24<08:27, 129.51it/s]
# Number of moves made: 34225; Target caught: True.

# %%
from main import test_map7
caught, numofmoves = test_map7(N=30000, K=1000, epsilon=10)
print('Number of moves made: {}; Target caught: {}.\n'.format(numofmoves, caught))
# Out:
#  65%|██████▌   | 65425/100000 [08:04<00:25, 1374.80it/s]
# robotpos = (2,4007)
# targetpos = (2,4006)
# total time = 451.73095178604126s
# average moving time/step = 0.006890764411892752s
#  66%|██████▌   | 65555/100000 [08:05<04:15, 135.06it/s]
# Number of moves made: 65556; Target caught: True.

# %%
from main import test_map7
caught, numofmoves = test_map7(N=10000, K=1000, epsilon=10)
print('Number of moves made: {}; Target caught: {}.\n'.format(numofmoves, caught))
# Out:
#  26%|██▋       | 26418/100000 [00:55<00:53, 1381.10it/s]
# robotpos = (2,4007)
# targetpos = (2,4006)
# total time = 45.345720529556274s
# average moving time/step = 0.0017097398585912177s
#  27%|██▋       | 26521/100000 [00:55<02:34, 474.26it/s]
# Number of moves made: 26522; Target caught: True.

# %%
from main import test_map7
caught, numofmoves = test_map7(N=30000, K=1000, epsilon=3)
print('Number of moves made: {}; Target caught: {}.\n'.format(numofmoves, caught))
# Out:
# 100%|██████████| 100000/100000 [15:19<00:00, 108.72it/s]
# Number of moves made: 100000; Target caught: False.

# %%
from main import test_map7
caught, numofmoves = test_map7(N=10000, K=1000, epsilon=3)
print('Number of moves made: {}; Target caught: {}.\n'.format(numofmoves, caught))
# Out:
#  40%|███▉      | 39594/100000 [02:24<00:41, 1470.83it/s]
# robotpos = (2,4006)
# targetpos = (3,4007)
# total time = 127.20831251144409s
# average moving time/step = 0.003200370144697698s
#  40%|███▉      | 39747/100000 [02:26<03:42, 270.91it/s]
# Number of moves made: 39748; Target caught: True.

# %%
from main import test_map7
caught, numofmoves = test_map7(N=10000, K=100, epsilon=5)
print('Number of moves made: {}; Target caught: {}.\n'.format(numofmoves, caught))
# Out:
# 100%|██████████| 100000/100000 [15:02<00:00, 110.85it/s]
# Number of moves made: 100000; Target caught: False.

# %%
from main import test_map7
caught, numofmoves = test_map7(N=10000, K=2000, epsilon=5)
print('Number of moves made: {}; Target caught: {}.\n'.format(numofmoves, caught))
# Out:
#  51%|█████     | 50957/100000 [04:17<00:31, 1549.27it/s]
# robotpos = (2,4007)
# targetpos = (2,4006)
# total time = 234.45209574699402s
# average moving time/step = 0.004587205943005166s
#  51%|█████     | 51109/100000 [04:20<04:09, 196.17it/s]
# Number of moves made: 51110; Target caught: True.

# %%
from main import test_map7
caught, numofmoves = test_map7(N=10000, K=1000, epsilon=6)
print('Number of moves made: {}; Target caught: {}.\n'.format(numofmoves, caught))
# Out:
#  19%|█▊        | 18736/100000 [00:50<00:56, 1426.01it/s]
# robotpos = (4997,4904)
# targetpos = (4998,4904)
# total time = 44.05004262924194s
# average moving time/step = 0.002330936746176418s
#  19%|█▉        | 18897/100000 [00:51<03:39, 369.20it/s]
# Number of moves made: 18898; Target caught: True.

# %%
from main import test_map7
caught, numofmoves = test_map7(N=20000, K=2000, epsilon=2)
print('Number of moves made: {}; Target caught: {}.\n'.format(numofmoves, caught))
# Out:
# 100%|██████████| 100000/100000 [17:03<00:00, 97.74it/s]
# Number of moves made: 100000; Target caught: False.

# %%
from main import test_map7
caught, numofmoves = test_map7(N=20000, K=1000, epsilon=5)
print('Number of moves made: {}; Target caught: {}.\n'.format(numofmoves, caught))
# Out:
# 100%|██████████| 100000/100000 [13:29<00:00, 123.57it/s]
# Number of moves made: 100000; Target caught: False.

# %%
from main import test_map7
caught, numofmoves = test_map7(N=20000, K=1000, epsilon=10)
print('Number of moves made: {}; Target caught: {}.\n'.format(numofmoves, caught))
# Out:
# 100%|██████████| 100000/100000 [11:00<00:00, 151.42it/s]
# Number of moves made: 100000; Target caught: False.
